# %% [markdown]
# #IncodeVision
# #Name of Student : Kalpesh Rajendra Patil

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("Messy_Employee_dataset.csv")

# View first rows
print(df.head())

# Check structure
print(df.info())
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# 3              Good         True
# 4              Poor        False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   object
#  1   First_Name         1020 non-null   object
#  2   Last_Name          1020 non-null   object
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   object
#  5   Status             1020 non-null   object
#  6   Join_Date          1020 non-null   object
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   object
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   object
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 88.8+ KB
# None

# %% [markdown]
# **Check Missing Values**

# %%
print(df.isnull().sum())
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                  211
# Department_Region      0
# Status                 0
# Join_Date              0
# Salary                24
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# dtype: int64

# %% [markdown]
# **Handle Missing Values**

# %%
# Fill numeric columns with mean
for col in df.select_dtypes(include=np.number):
    df[col].fillna(df[col].mean(), inplace=True)

# Fill categorical columns with mode
for col in df.select_dtypes(include='object'):
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_15422/1901314395.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /tmp/ipykernel_15422/1901314395.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %% [markdown]
# **Remove Duplicates**

# %%
print("Duplicates before:", df.duplicated().sum())

df.drop_duplicates(inplace=True)

print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %% [markdown]
# **Fix Column Names**

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %% [markdown]
# **Handle Inconsistent Data**

# %%
df['department_region'] = df['department_region'].str.lower().str.strip()

df['salary'] = df['salary'].replace('[$,]', '', regex=True)
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')

df['join_date'] = pd.to_datetime(df['join_date'], errors='coerce')

# %% [markdown]
# **Handle Outliers**

# %%
# Example: remove extreme salary values
df = df[df['salary'] < df['salary'].quantile(0.99)]

# %% [markdown]
# **Final Check**

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1009 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        1009 non-null   object
#  1   first_name         1009 non-null   object
#  2   last_name          1009 non-null   object
#  3   age                1009 non-null   float64
#  4   department_region  1009 non-null   object
#  5   status             1009 non-null   object
#  6   join_date          1009 non-null   datetime64[ns]
#  7   salary             1009 non-null   float64
#  8   email              1009 non-null   object
#  9   phone              1009 non-null   int64
#  10  performance_score  1009 non-null   object
#  11  remote_work        1009 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 95.6+ KB
# None
#                age                      join_date         salary         phone
# count  1009.000000                           1009    1009.000000  1.009000e+03
# mean     32.474546  2022-07-27 11:40:44.003964160   84780.070856 -4.934756e+09
# min      25.000000            2020-01-01 00:00:00   50047.320000 -9.994973e+09
# 25%      30.000000            2021-04-15 00:00:00   68512.100000 -7.315391e+09
# 50%      32.484549            2022-08-12 00:00:00   85155.056396 -4.938174e+09
# 75%      35.000000            2023-11-02 00:00:00   99951.430000 -2.517630e+09
# max      40.000000            2024-12-29 00:00:00  118959.280000 -3.896086e+06
# std       5.051142                            NaN   19411.820972  2.813097e+09

# %% [markdown]
# **Save Clean Dataset**

# %%
df.to_csv("Cleaned_Employee_dataset.csv", index=False)
